# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryyeung/my-first-binder/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
resp = requests.get('https://www.apple.com/ac/ac-video-posterframe/4.0/images/ac_video_poster_960x540.jpg')

# %%
print(resp.text)
# Out:
#
#
# �;ۦN�'�������;�7��?tb���6���2m�'�
# ?�6�J%��k�69�ے�7
# ?!�
# ?���Җ�F���j����1n��DûځP	[L"!�>�kU#Ț$�U�
# p60��u�K�L;���R��rRy$���0�3�
# �?�ji��,�̏�q�*�\����y�����99�R&D���(U�1Z<��7W�š:�~x�/>/�X5o/��}��a.g��:���#	b�[�G[�h�;�j�R��u����,`yuz	̨�����(�a���X�G:C-��c��Q]#s��E��;ȁ�5ce���y��7���Y�����I����~]��

# %%
from IPython.display import display
from PIL import Image
import IPython

# %%
url='https://www.apple.com/ac/ac-video-posterframe/4.0/images/ac_video_poster_960x540.jpg'
im = Image.open(requests.get(url, stream=True).raw)
im.show()
IPython.display.Image(url, width = 250)
